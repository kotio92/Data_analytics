# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Reading Files

# %% [markdown]
# In questo file vediamo come importare dati di tipo tabulare e caricarli come Dataframe

# %%
dataset = pd.read_csv('yelp.csv', index_col=None)
print(type(dataset))
dataset.head()

# L'opzione index_col mi consente di selezionare una delle colonne come indice; ad es se voglio selezionare business_id
# come indice scrivo index_col=0; se voglio un indice che non corrisponde a nessuna colonna lo setto a False oppure None

# il campo index_col si valorizza col nome della colonna che voglio usare come index; scrivendo None
# dico che non c'è nessuna colonna che voglio usare come indice
# Out:
# <class 'pandas.core.frame.DataFrame'>
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3  uZetl9T0NcROGOyFfughhg     1       2      0
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0

# %% [markdown]
# Il file csv è stato importato come Dataframe

# %%
print(len(dataset))   # ritorna il numero di righe
print(dataset.shape)  # ritorna il numero di righe e colonne
# Out:
# 10000
# (10000, 10)

# %% [markdown]
# ## Data Operations

# %% [markdown]
# ### Selezione di righe/colonne

# %% [markdown]
# Una colonna o una riga di un Dataframe possono essere selezionati tramite il nome delle colonne e righe (indice).

# %%
# Colonna
print(dataset['business_id'])

# Prime 2 colonne
print(dataset[['business_id','user_id']])

# Riga
print(dataset.loc[0:3])          # prime 3 righe
# Out:
# 0       9yKzy9PApeiPPOUJEtnvkg
# 1       ZRJwVLyzEJq1VAihDhYiow
# 2       6oRAC4uyJCsJl1X0WZpVSA
# 3       _1QQZuf4zZOyFCvXc0o6Vg
# 4       6ozycU1RpktNG2-1BroVtw
#                  ...
# 9995    VY_tvNUCCXGXQeSvJl757Q
# 9996    EKzMHI1tip8rC1-ZAy64yg
# 9997    53YGfwmbW73JhFiemNeyzQ
# 9998    9SKdOoDHcFoxK5ZtsgHJoA
# 9999    pF7uRzygyZsltbmVpjIyvw
# Name: business_id, Length: 10000, dtype: object
#                  business_id                 user_id
# 0     9yKzy9PApeiPPOUJEtnvkg  rLtl8ZkDX5vH5nAx9C3q5Q
# 1     ZRJwVLyzEJq1VAihDhYiow  0a2KyEL0d3Yb1V6aivbIuQ
# 2     6oRAC4uyJCsJl1X0WZpVSA  0hT2KtfLiobPvh6cDC8JQg
# 3     _1QQZuf4zZOyFCvXc0o6Vg  uZetl9T0NcROGOyFfughhg
# 4     6ozycU1RpktNG2-1BroVtw  vYmM4KTsC8ZfQBg-j5MWkw
# ...                      ...                     ...
# 9995  VY_tvNUCCXGXQeSvJl757Q  _eqQoPtQ3e3UxLE4faT6ow
# 9996  EKzMHI1tip8rC1-ZAy64yg  ROru4uk5SaYc3rg8IU7SQw
# 9997  53YGfwmbW73JhFiemNeyzQ  gGbN1aKQHMgfQZkqlsuwzg
# 9998  9SKdOoDHcFoxK5ZtsgHJoA  0lyVoNazXa20WzUyZPLaQQ
# 9999  pF7uRzygyZsltbmVpjIyvw  KSBFytcdjPKZgXKQnYQdkA
#
# [10000 rows x 2 columns]
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3  uZetl9T0NcROGOyFfughhg     1       2      0

# %% [markdown]
# ### Filtraggio dei dati

# %% [markdown]
# Il filtraggio dei dati si fa andando a specificare una condizione (booleana) all'interno delle parentesi quadre.

# %%
dataset[dataset['cool']>1]     # mi ritorna tutte le righe del dataframe con cool > 1

# N.B: quando passo una condizione booleana per il filtraggio, mi vengono restituiti i risultati corrispondenti a 'True'
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 5     -yxfBYGB6SEqszmxJxd97A  2007-12-13  m2CKSsepBCoRYWxiRUsxAg      4
# 6     zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A      5
# 16    supigcPNO9IKo6olaTNV-g  2008-10-12  HXP_0Ul-FCmA4f-k9CqvaQ      3
# 18    b5cEoKR8iQliq-yT2_O0LQ  2009-03-06  v0cTd3PNpYCkTyGKSpOfGA      3
# ...                      ...         ...                     ...    ...
# 9977  iDYzGVIF1TDWdjHNgNjCVw  2012-10-30  qaNZyCUJA6Yp0mvPBCknPQ      5
# 9979  GV1P1x9eRb4iZHCxj5_IjA  2012-12-07  eVUs1C4yaVJNrc7SGTAheg      5
# 9980  GHYOl_cnERMOhkCK_mGAlA  2011-07-03  Q-y3jSqccdytKxAyo1J0Xg      5
# 9981  AX8lx9wHNYT45lyd7pxaYw  2008-11-27  IyunTh7jnG7v3EYwfF3hPw      5
# 9992  f96lWMIAUhYIYy9gOktivQ  2009-03-10  YF17z7HWlMj6aezZc-pVEw      5
#
#                                                    text    type  \
# 0     My wife took me here on my birthday for breakf...  review
# 5     Quiessence is, simply put, beautiful.  Full wi...  review
# 6     Drop what you're doing and drive here. After I...  review
# 16    We went here on a Saturday afternoon and this ...  review
# 18    I met a friend for lunch yesterday. \n\nLoved ...  review
# ...                                                 ...     ...
# 9977  Why did I wait so long to try this neighborhoo...  review
# 9979  Highly recommend. This is my second time here ...  review
# 9980  5 stars for the great $5 happy hour specials. ...  review
# 9981  We brought the entire family to Giuseppe's las...  review
# 9992  I'm not normally one to jump at reviewing a ch...  review
#
#                      user_id  cool  useful  funny
# 0     rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 5     sqYN3lNgvPbPCTRsMFu27g     4       3      1
# 6     wFweIWhv2fREZV_dYkz_1g     7       7      4
# 16    SBbftLzfYYKItOMFwOTIJg     3       4      2
# 18    UsULgP4bKA8RMzs8dQzcsA     5       6      4
# ...                      ...   ...     ...    ...
# 9977  Id-8-NMEKxeXBR44eUdDeA     3       6      3
# 9979  bJFdmJJxfXgCYA5DMmyeqQ     2       2      1
# 9980  xZvRLPJ1ixhFVomkXSfXAw     6       6      4
# 9981  fczQCSmaWF78toLEmb0Zsw    10       9      5
# 9992  W_QXYA7A0IhMrvbckz7eVg     2       3      2
#
# [1755 rows x 10 columns]

# %%
# Il filtraggio lo posso fare anche sulle colonne
dataset['business_id']
# Out:
# 0       9yKzy9PApeiPPOUJEtnvkg
# 1       ZRJwVLyzEJq1VAihDhYiow
# 2       6oRAC4uyJCsJl1X0WZpVSA
# 3       _1QQZuf4zZOyFCvXc0o6Vg
# 4       6ozycU1RpktNG2-1BroVtw
#                  ...
# 9995    VY_tvNUCCXGXQeSvJl757Q
# 9996    EKzMHI1tip8rC1-ZAy64yg
# 9997    53YGfwmbW73JhFiemNeyzQ
# 9998    9SKdOoDHcFoxK5ZtsgHJoA
# 9999    pF7uRzygyZsltbmVpjIyvw
# Name: business_id, Length: 10000, dtype: object

# %% [markdown]
# Proviamo a combinare i filtri.

# %%
print(dataset[['cool','user_id','stars']][dataset['cool']>5])    # applico un filtro per visulizzare solo le righe con 'cool>5'
                                                                 # mi faccio restituire solo le 3 colonne che mi interessano
# Out:
#       cool                 user_id  stars
# 6        7  wFweIWhv2fREZV_dYkz_1g      5
# 82      11  mfvezpz6ohS0NQk3DZdvqQ      5
# 90       7  8tbXmjYGsYFZXk6ppuwRWQ      1
# 112      6  QKW7sYPWPSsIcWqSiDzChQ      5
# 125      8  C6IOtaaYdLIT5fWd7ZYIuA      5
# ...    ...                     ...    ...
# 9904    13  eBwBjylS66qPcHs2_ajLag      4
# 9942     8  l81ILmOhky5bG7o4r3rkhQ      5
# 9956    14  P2kVk4cIWyK4e4h14RhK-Q      5
# 9980     6  xZvRLPJ1ixhFVomkXSfXAw      5
# 9981    10  fczQCSmaWF78toLEmb0Zsw      5
#
# [282 rows x 3 columns]

# %%
dataset[['business_id','user_id','cool','stars']][(dataset['cool']>5)&(dataset['stars']>3)]

# applico un filtro per selezionare le righe con 'cool>5' e 'stars>3' e mi faccio restituire solo le colonne
# che mi interessano
# Out:
#                  business_id                 user_id  cool  stars
# 6     zp713qNhx8d9KCJJnrw1xA  wFweIWhv2fREZV_dYkz_1g     7      5
# 82    d7_jkx0VPx3uHsUl18iHMQ  mfvezpz6ohS0NQk3DZdvqQ    11      5
# 112   StiQ_lcCY8sX4JI-J6Mufg  QKW7sYPWPSsIcWqSiDzChQ     6      5
# 125   rZbHg4ACfN3iShdsT47WKQ  C6IOtaaYdLIT5fWd7ZYIuA     8      5
# 144   zp713qNhx8d9KCJJnrw1xA  dQO0tQISZyb9L4d5ASnXyQ    16      5
# ...                      ...                     ...   ...    ...
# 9904  3n9mSKySEv3G03YjcU-YOQ  eBwBjylS66qPcHs2_ajLag    13      4
# 9942  iV7D7fHKb-bF9fCL_bEMtA  l81ILmOhky5bG7o4r3rkhQ     8      5
# 9956  7tPe20uDErh-iSkfNEWzVQ  P2kVk4cIWyK4e4h14RhK-Q    14      5
# 9980  GHYOl_cnERMOhkCK_mGAlA  xZvRLPJ1ixhFVomkXSfXAw     6      5
# 9981  AX8lx9wHNYT45lyd7pxaYw  fczQCSmaWF78toLEmb0Zsw    10      5
#
# [216 rows x 4 columns]

# %% [markdown]
# Altre operazioni

# %%
# Conteggio delle righe risultato dall'applicazione del filtro
print(dataset[['business_id','user_id','cool','stars']][(dataset['cool']>5)&(dataset['stars']>3)].count())
# Out:
# business_id    216
# user_id        216
# cool           216
# stars          216
# dtype: int64

# %%
# Statistiche sul dataset risultante dall'applicazione del filtro
print(dataset[['business_id','user_id','cool','stars']][(dataset['cool']>5)&(dataset['stars']>3)].describe())
# Out:
#              cool       stars
# count  216.000000  216.000000
# mean     9.986111    4.481481
# std      6.513299    0.500818
# min      6.000000    4.000000
# 25%      6.000000    4.000000
# 50%      8.000000    4.000000
# 75%     11.000000    5.000000
# max     77.000000    5.000000

# %%
dataset['stars'][(dataset['stars']>4)|(dataset['stars']<2)].count()

# Sto dicendo: conta le righe dove 'stars'>4 e quelle dove 'stars < 2'
# Out:
# 4086

# %%
# Facciamo la verifica di quanto detto sopra

dataset[dataset['stars']>4].count() + dataset[dataset['stars']<2].count() == 4086
# Out:
# business_id    True
# date           True
# review_id      True
# stars          True
# text           True
# type           True
# user_id        True
# cool           True
# useful         True
# funny          True
# dtype: bool

# %% [markdown]
# ### Sorting

# %% [markdown]
# Quando andiamo ad applicare un filtro sul dataset i risultati vengono di deafult ordinati per indice

# %%
dataset[dataset['cool']==5].head()
# Out:
#                 business_id        date               review_id  stars  \
# 18   b5cEoKR8iQliq-yT2_O0LQ  2009-03-06  v0cTd3PNpYCkTyGKSpOfGA      3
# 218  h6jfMpTZpNduLG0wE2tbaw  2008-12-21  lG3Y6LPASX8MyqDedIpBGQ      2
# 250  PWG28q4JFOc8FiRBjnfCkA  2012-10-24  W5AdcbX_qzSYQ5VbwWyJsQ      3
# 409  bbi-76L0uvQRrno57Qjpaw  2012-11-28  wC9w5m_ROb0dLWMqVXjbDw      4
# 452  eTbtfgUtfewdncgVf2CbWw  2007-03-22  wAL9qe2PCJORCcAoCL7Gvw      5
#
#                                                   text    type  \
# 18   I met a friend for lunch yesterday. \n\nLoved ...  review
# 218  Ate here months ago.  Was excited to finally f...  review
# 250  Alright, so here is my two cents on Brat Haus....  review
# 409  Handmade, in-store fine candies aand chocolate...  review
# 452  WOW this place is good!  SO good!  And not jus...  review
#
#                     user_id  cool  useful  funny
# 18   UsULgP4bKA8RMzs8dQzcsA     5       6      4
# 218  0bNXP9quoJEgyVZu9ipGgQ     5       7      3
# 250  lmiDCrmas8TxRsbIGZX9Pg     5       6      3
# 409  EcgpGtxB5916NPqvXwMcjQ     5      10      2
# 452  l53FUDHRHLg7BQ89KgAtxQ     5       5      0

# %% [markdown]
# Quello che si vede nella cella soprastante si ottiene perchè viene applicato di default il metodo *sort_index* della classe
# Dataframe.

# %%
dataset[dataset['cool']==5].sort_index().head()
# Out:
#                 business_id        date               review_id  stars  \
# 18   b5cEoKR8iQliq-yT2_O0LQ  2009-03-06  v0cTd3PNpYCkTyGKSpOfGA      3
# 218  h6jfMpTZpNduLG0wE2tbaw  2008-12-21  lG3Y6LPASX8MyqDedIpBGQ      2
# 250  PWG28q4JFOc8FiRBjnfCkA  2012-10-24  W5AdcbX_qzSYQ5VbwWyJsQ      3
# 409  bbi-76L0uvQRrno57Qjpaw  2012-11-28  wC9w5m_ROb0dLWMqVXjbDw      4
# 452  eTbtfgUtfewdncgVf2CbWw  2007-03-22  wAL9qe2PCJORCcAoCL7Gvw      5
#
#                                                   text    type  \
# 18   I met a friend for lunch yesterday. \n\nLoved ...  review
# 218  Ate here months ago.  Was excited to finally f...  review
# 250  Alright, so here is my two cents on Brat Haus....  review
# 409  Handmade, in-store fine candies aand chocolate...  review
# 452  WOW this place is good!  SO good!  And not jus...  review
#
#                     user_id  cool  useful  funny
# 18   UsULgP4bKA8RMzs8dQzcsA     5       6      4
# 218  0bNXP9quoJEgyVZu9ipGgQ     5       7      3
# 250  lmiDCrmas8TxRsbIGZX9Pg     5       6      3
# 409  EcgpGtxB5916NPqvXwMcjQ     5      10      2
# 452  l53FUDHRHLg7BQ89KgAtxQ     5       5      0

# %% [markdown]
# Tuttavia possiamo anche decidere di ordinare i risultati utilizzando un altro indice a nostra scelta col metodo *sort_values*

# %%
dataset[dataset['cool']==5].sort_values('funny').head()
# Out:
#                  business_id        date               review_id  stars  \
# 1823  IVc23uY-36WUNYoIbz42Fg  2008-01-13  Kibj2ajzr5yyNrEkpIk_BQ      4
# 5795  xPbUPBWS6k31qgUfUODmnw  2009-08-04  GPRCZ2tVtGLXYUDWTYYIhg      5
# 2215  whAFYa0ZyTIRe7GamYAmsw  2010-04-03  qm7XZ40KNqh2cJTlnXy91g      4
# 1203  o2rrTbAxGXrdQKQvKDcGiA  2008-03-12  5KNRveSLv3bPAsyc-32JHg      5
# 5252  NH67MdKaFGNcP-dlu56pyw  2009-01-16  OUYW_ylJmTRZFRtTEMzAbQ      4
#
#                                                    text    type  \
# 1823  I absolutely love the atmosphere and vibe of S...  review
# 5795  You know when you get a really good cut and co...  review
# 2215  Went for the free "Movies in the Park Free Fam...  review
# 1203  I would not survive without Channel 8. i reall...  review
# 5252  Impressive dinner tonight!  However, it was a ...  review
#
#                      user_id  cool  useful  funny
# 1823  -txH2zJSBZQHO6RWvoWXuQ     5       5      0
# 5795  q9XgOylNsSbqZqF_SO3-OQ     5       7      0
# 2215  hq0WUfau1Mh3GyHn8oVdNQ     5       4      0
# 1203  90a6z--_CUrl84aCzZyPsg     5       3      0
# 5252  0bNXP9quoJEgyVZu9ipGgQ     5       6      0

# %% [markdown]
# ### Null values

# %% [markdown]
# Ora concentriamoci sui valori mancanti ('**NULL**') del dataset.

# %% [markdown]
# Tali celle sono riempite col valore '**NaN**'.

# %%
dataset.isnull().describe()  # non ci sono valori nulli, quindi proviamo a modificare i dataset eliminando qualche valore

# La funzione isnull() restituisce True laddove trova la cella vuota
# Out:
#        business_id   date review_id  stars   text   type user_id   cool  \
# count        10000  10000     10000  10000  10000  10000   10000  10000
# unique           1      1         1      1      1      1       1      1
# top          False  False     False  False  False  False   False  False
# freq         10000  10000     10000  10000  10000  10000   10000  10000
#
#        useful  funny
# count   10000  10000
# unique      1      1
# top     False  False
# freq    10000  10000

# %%
dataset_modified = pd.read_csv('yelp_modified.csv',index_col=None)
dataset_modified.head(22)
# Out:
#                business_id        date               review_id  stars  \
# 0   9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A    5.0
# 1   ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA    5.0
# 2   6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ    4.0
# 3   _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA    5.0
# 4   6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw    5.0
# 5   -yxfBYGB6SEqszmxJxd97A  2007-12-13  m2CKSsepBCoRYWxiRUsxAg    4.0
# 6   zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A    5.0
# 7   hW0Ne_HTHEAgGF1rAdmR-g  2012-07-12  JL7GXJ9u4YMx7Rzs05NfiQ    4.0
# 8   wNUea3IXZWD63bbOQaOH-g         NaN  XtnfnYmnJYi71yIuGsXIUA    NaN
# 9   nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ    5.0
# 10  AsSCv0q_BWqIe3mX2JqsOQ  2010-06-16  E11jzpKz9Kw5K7fuARWfRw    5.0
# 11  e9nN4XxjdHj4qtKCOPq_vg  2011-10-21  3rPt0LxF7rgmEUrznoH22w    5.0
# 12  h53YuCiIDfEFSJCQpk8v1g  2010-01-11  cGnKNX3I9rthE0-TH24-qA    5.0
# 13  WGNIYMeXPyoWav1APUq7jA  2011-12-23  FvEEw1_OsrYdvwLV5Hrliw    4.0
# 14  yc5AH9H71xJidA_J2mChLA  2010-05-20  pfUwBKYYmUXeiwrhDluQcw    4.0
# 15  Vb9FPCEL6Ly24PNxLBaAFw  2011-03-20  HvqmdqWcerVWO3Gs6zbrOw    2.0
# 16  supigcPNO9IKo6olaTNV-g  2008-10-12  HXP_0Ul-FCmA4f-k9CqvaQ    3.0
# 17  O510Re68mOy9dU490JTKCg  2010-05-03  j4SIzrIy0WrmW4yr4--Khg    5.0
# 18  b5cEoKR8iQliq-yT2_O0LQ  2009-03-06  v0cTd3PNpYCkTyGKSpOfGA    3.0
# 19  4JzzbSbK9wmlOBJZWYfuCg  2011-11-17  a0lCu-j2Sk_kHQsZi_eNgw    4.0
# 20  8FNO4D3eozpIjj0k3q5Zbg  2008-10-08  MuqugTuR5DdIPcZ2IVP3aQ    3.0
# 21                     NaN  2011-06-28  LmuKVFh03Uz318VKnUWrxA    5.0
#
#                                                  text    type  \
# 0                                                 NaN  review
# 1   I have no idea why some people give bad review...  review
# 2   love the gyro plate. Rice is so good and I als...  review
# 3   Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4   General Manager Scott Petello is a good egg!!!...  review
# 5   Quiessence is, simply put, beautiful.  Full wi...  review
# 6   Drop what you're doing and drive here. After I...  review
# 7   Luckily, I didn't have to travel far to make m...  review
# 8   Definitely come for Happy hour! Prices are ama...  review
# 9   Nobuo shows his unique talents with everything...  review
# 10  The oldish man who owns the store is as sweet ...  review
# 11  Wonderful Vietnamese sandwich shoppe. Their ba...  review
# 12  They have a limited time thing going on right ...  review
# 13  Good tattoo shop. Clean space, multiple artist...  review
# 14  I'm 2 weeks new to Phoenix. I looked up Irish ...  review
# 15  Was it worth the 21$ for a salad and small piz...  review
# 16  We went here on a Saturday afternoon and this ...  review
# 17  okay this is the best place EVER! i grew up sh...  review
# 18  I met a friend for lunch yesterday. \n\nLoved ...  review
# 19  They've gotten better and better for me in the...  review
# 20  DVAP....\n\nYou have to go at least once in yo...  review
# 21  This place shouldn't even be reviewed - becaus...  review
#
#                    user_id  cool  useful  funny
# 0   rLtl8ZkDX5vH5nAx9C3q5Q     2     5.0      0
# 1   0a2KyEL0d3Yb1V6aivbIuQ     0     0.0      0
# 2   0hT2KtfLiobPvh6cDC8JQg     0     1.0      0
# 3   uZetl9T0NcROGOyFfughhg     1     2.0      0
# 4   vYmM4KTsC8ZfQBg-j5MWkw     0     0.0      0
# 5   sqYN3lNgvPbPCTRsMFu27g     4     3.0      1
# 6   wFweIWhv2fREZV_dYkz_1g     7     7.0      4
# 7   1ieuYcKS7zeAv_U15AB13A     0     1.0      0
# 8   Vh_DlizgGhSqQh4qfZ2h6A     0     0.0      0
# 9   sUNkXg8-KFtCMQDV6zRzQg     0     1.0      0
# 10  -OMlS6yWkYjVldNhC31wYg     1     3.0      1
# 11  C1rHp3dmepNea7XiouwB6Q     1     1.0      0
# 12  UPtysDF6cUDUxq2KY-6Dcg     1     2.0      0
# 13  Xm8HXE1JHqscXe5BKf0GFQ     1     2.0      0
# 14  JOG-4G4e8ae3lx_szHtR8g     1     1.0      0
# 15  ylWOj2y7TV2e3yYeWhu2QA     0     NaN      0
# 16  SBbftLzfYYKItOMFwOTIJg     3     4.0      2
# 17  u1KWcbPMvXFEEYkZZ0Yktg     0     0.0      0
# 18  UsULgP4bKA8RMzs8dQzcsA     5     6.0      4
# 19  nDBly08j5URmrHQ2JCbyiw     1     1.0      1
# 20  C6IOtaaYdLIT5fWd7ZYIuA     2     4.0      1
# 21  YN3ZLOdg8kpnfbVcIhuEZA     1     1.0      2

# %%
dataset_modified.isnull().describe()    # Come si vede, ci sono dei valori nulli
# Out:
#        business_id   date review_id  stars   text   type user_id   cool  \
# count        10000  10000     10000  10000  10000  10000   10000  10000
# unique           2      2         1      2      2      1       1      1
# top          False  False     False  False  False  False   False  False
# freq          9999   9999     10000   9998   9998  10000   10000  10000
#
#        useful  funny
# count   10000  10000
# unique      2      1
# top     False  False
# freq     9999  10000

# %%
dataset_modified['business_id'].isnull().describe()   # ad esempio si vede che nella colonna business_id c'è 1 valore nullo
# Out:
# count     10000
# unique        2
# top       False
# freq       9999
# Name: business_id, dtype: object

# %%
dataset_modified[['business_id','text','user_id']][dataset_modified['business_id'].isnull()]

# così facendo sto filtrando le righe dove il campo 'business_id' non è valorizzato
# Out:
#    business_id                                               text  \
# 21         NaN  This place shouldn't even be reviewed - becaus...
#
#                    user_id
# 21  YN3ZLOdg8kpnfbVcIhuEZA

# %%
dataset_modified[['business_id','text','user_id','useful']][dataset_modified['useful'].isnull()]

# così facendo sto filtrando le righe dove il campo 'useful' non risulta valorizzato
# Out:
#                business_id                                               text  \
# 15  Vb9FPCEL6Ly24PNxLBaAFw  Was it worth the 21$ for a salad and small piz...
#
#                    user_id  useful
# 15  ylWOj2y7TV2e3yYeWhu2QA     NaN

# %% [markdown]
# Possiamo anche usare il metodo *fillna* (disponibile per classe Series e classe Dataframe) per riempire
# le celle non valorizzate.

# %%
dataset_modified = dataset_modified[['business_id','text','user_id','useful']].fillna('No Value!').head(16)

# %%
dataset_modified.head(16)
# Out:
#                business_id                                               text  \
# 0   9yKzy9PApeiPPOUJEtnvkg                                          No Value!
# 1   ZRJwVLyzEJq1VAihDhYiow  I have no idea why some people give bad review...
# 2   6oRAC4uyJCsJl1X0WZpVSA  love the gyro plate. Rice is so good and I als...
# 3   _1QQZuf4zZOyFCvXc0o6Vg  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...
# 4   6ozycU1RpktNG2-1BroVtw  General Manager Scott Petello is a good egg!!!...
# 5   -yxfBYGB6SEqszmxJxd97A  Quiessence is, simply put, beautiful.  Full wi...
# 6   zp713qNhx8d9KCJJnrw1xA  Drop what you're doing and drive here. After I...
# 7   hW0Ne_HTHEAgGF1rAdmR-g  Luckily, I didn't have to travel far to make m...
# 8   wNUea3IXZWD63bbOQaOH-g  Definitely come for Happy hour! Prices are ama...
# 9   nMHhuYan8e3cONo3PornJA  Nobuo shows his unique talents with everything...
# 10  AsSCv0q_BWqIe3mX2JqsOQ  The oldish man who owns the store is as sweet ...
# 11  e9nN4XxjdHj4qtKCOPq_vg  Wonderful Vietnamese sandwich shoppe. Their ba...
# 12  h53YuCiIDfEFSJCQpk8v1g  They have a limited time thing going on right ...
# 13  WGNIYMeXPyoWav1APUq7jA  Good tattoo shop. Clean space, multiple artist...
# 14  yc5AH9H71xJidA_J2mChLA  I'm 2 weeks new to Phoenix. I looked up Irish ...
# 15  Vb9FPCEL6Ly24PNxLBaAFw  Was it worth the 21$ for a salad and small piz...
#
#                    user_id     useful
# 0   rLtl8ZkDX5vH5nAx9C3q5Q          5
# 1   0a2KyEL0d3Yb1V6aivbIuQ          0
# 2   0hT2KtfLiobPvh6cDC8JQg          1
# 3   uZetl9T0NcROGOyFfughhg          2
# 4   vYmM4KTsC8ZfQBg-j5MWkw          0
# 5   sqYN3lNgvPbPCTRsMFu27g          3
# 6   wFweIWhv2fREZV_dYkz_1g          7
# 7   1ieuYcKS7zeAv_U15AB13A          1
# 8   Vh_DlizgGhSqQh4qfZ2h6A          0
# 9   sUNkXg8-KFtCMQDV6zRzQg          1
# 10  -OMlS6yWkYjVldNhC31wYg          3
# 11  C1rHp3dmepNea7XiouwB6Q          1
# 12  UPtysDF6cUDUxq2KY-6Dcg          2
# 13  Xm8HXE1JHqscXe5BKf0GFQ          2
# 14  JOG-4G4e8ae3lx_szHtR8g          1
# 15  ylWOj2y7TV2e3yYeWhu2QA  No Value!

# %% [markdown]
# ### String Operations

# %% [markdown]
# Esempio di ricerca di una stringa.

# %%
print(dataset['business_id'][dataset['business_id']== '6oRAC4uyJCsJl1X0WZpVSA'].count())
dataset[dataset['business_id'] == '6oRAC4uyJCsJl1X0WZpVSA']
# Out:
# 12
#                  business_id        date               review_id  stars  \
# 2     6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 543   6oRAC4uyJCsJl1X0WZpVSA  2012-03-22  6Gb_wp8N0TFXcYDkuRyWOQ      5
# 854   6oRAC4uyJCsJl1X0WZpVSA  2011-07-08  qdmWiBaolhOnibLQh5W_Gg      5
# 923   6oRAC4uyJCsJl1X0WZpVSA  2010-05-01  j2Eno7wxttUkoeClhctwkQ      4
# 1052  6oRAC4uyJCsJl1X0WZpVSA  2012-07-24  NiqLX8pW-R2OrnjUxgyXkQ      5
# 1498  6oRAC4uyJCsJl1X0WZpVSA  2010-04-20  MDtjJub6L_2dgkSxF1lipA      5
# 2455  6oRAC4uyJCsJl1X0WZpVSA  2010-05-17  XABPPSphqJ4PVrZbZ_AjtA      4
# 3014  6oRAC4uyJCsJl1X0WZpVSA  2011-02-12  UcnkWyPd2MmLSjtmk-W0Kw      4
# 6405  6oRAC4uyJCsJl1X0WZpVSA  2012-04-20  ewd-GXTUEC5yaOndM0_sgw      4
# 7925  6oRAC4uyJCsJl1X0WZpVSA  2011-07-28  u9aMNOK1_eVF8PL_CpVSrg      5
# 9403  6oRAC4uyJCsJl1X0WZpVSA  2012-11-03  5ucisvItjJVLX5wfxXVcTA      5
# 9590  6oRAC4uyJCsJl1X0WZpVSA  2013-01-03  FJhI-HZIMHhnd9jab4I7Pw      5
#
#                                                    text    type  \
# 2     love the gyro plate. Rice is so good and I als...  review
# 543   The best gyro you will have in Arizona...\nor ...  review
# 854   My husband and I have been going here for a fe...  review
# 923   The place is nothing special, you can even thi...  review
# 1052  I had the pleasure of living across the street...  review
# 1498  This place is a gem. The food is amazing. It's...  review
# 2455  Haji-Baba is unique by being both a restaurant...  review
# 3014  Go for the food and you won't be disappointed,...  review
# 6405  So i'm not here to buy spices or shop for shee...  review
# 7925  Love love love this place.  Tasty with great p...  review
# 9403  Hands down the best middle eastern restaurant ...  review
# 9590  Awesome food. Highly recommend. Had gyros plat...  review
#
#                      user_id  cool  useful  funny
# 2     0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 543   QUTW6GQnEAJSqrzoUJ0m7Q     0       0      0
# 854   sbNbxmGNodDJukgSXBFD4Q     0       0      0
# 923   LqgGgWi3FLHBViX9tmZ9sw     1       1      0
# 1052  XpSZrY_Ym8GGx7SNEd0q9g     2       3      2
# 1498  YEVokKX9G9PgHJ_gK4gO_g     1       1      0
# 2455  kq5Pdsy8Znyh9KEkxWT_QA     0       0      0
# 3014  jXp0eFDh_LNO8JfcGlV3pw     2       2      0
# 6405  GRgBu4K7GOb3354esp_xkg     1       4      3
# 7925  fPHLPrymsyb6WSFFKoMrTQ     3       4      3
# 9403  e7_mPkNLzbyWMXOBpT0E5Q     1       0      0
# 9590  5j0hoUVgYJTyNshMXgJ4rg     0       0      0

# %% [markdown]
# Posso anche richiamare, per gli oggetti Series, i metodi propri della classe Stringa ('str').

# %%
dataset['business_id'].str.startswith('6o').head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: business_id, dtype: bool

# %%
dataset['business_id'].str.endswith('VSA').head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: business_id, dtype: bool

# %% [markdown]
# Attraverso il metodo rsplit prendo la Series dataset['date'] e la trasformo in una Series Di liste contenenti
# anno, mese, giorno.

# %%
dataset['date'].str.rsplit('-').head()
# Out:
# 0    [2011, 01, 26]
# 1    [2011, 07, 27]
# 2    [2012, 06, 14]
# 3    [2010, 05, 27]
# 4    [2012, 01, 05]
# Name: date, dtype: object

# %%
print(type(dataset['date'].str.rsplit('-').head()))           # Series
print(type(dataset['date'].str.rsplit('-').head()[0]))        # List
print(type(dataset['date'].str.rsplit('-').head()[0][0]))     # Stringa
print(dataset['date'].str.rsplit('-').head()[0])
print(dataset['date'].str.rsplit('-').head()[0][2])
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>
# <class 'str'>
# ['2011', '01', '26']
# 26

# %% [markdown]
# ### Value_counts

# %% [markdown]
# Col metodo *value_counts* ho la distribuzione di frequenza dei valori presenti in una certa colonna; si tratta di un metodo della classe Series.

# %%
print(type(dataset['stars'].value_counts()))

dataset['stars'].value_counts()

# Si vede quante righe hanno 5 stars, quante 4 ecc
# Out:
# <class 'pandas.core.series.Series'>
# 4    3526
# 5    3337
# 3    1461
# 2     927
# 1     749
# Name: stars, dtype: int64

# %%
dataset['stars'].value_counts().cumsum()    # distribuzione di frequenza cumulata
# Out:
# 4     3526
# 5     6863
# 3     8324
# 2     9251
# 1    10000
# Name: stars, dtype: int64

# %% [markdown]
# ### Groupby

# %% [markdown]
# Quello che abbiamo fatto pocanzi col metodo count_values() può essere fatto anche col metodo *groupby*; è un metodo della classe Dataframe di Pandas.

# %%
print(dataset.groupby(['stars']))   # questo metodo ritorna un oggetto di tipo 'DataFrameGroupBy', il quale a sua volta dispone
                                    # di vari metodi, fra cui il size()

dataset.groupby(['stars']).size()   # ritorna il conteggio di righe per ciascuno dei valori di 'stars'
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000014FC6586408>
# stars
# 1     749
# 2     927
# 3    1461
# 4    3526
# 5    3337
# dtype: int64

# %% [markdown]
# Il groupby può essere eseguito anche su più condizioni.

# %%
print(dataset.groupby(['type','stars']).size())

print(dataset.groupby(['type','stars','cool']).size().head())
# Out:
# type    stars
# review  1         749
#         2         927
#         3        1461
#         4        3526
#         5        3337
# dtype: int64
# type    stars  cool
# review  1      0       549
#                1       118
#                2        29
#                3        24
#                4        10
# dtype: int64

# %% [markdown]
# Possiamo anche specificare un filtro sul groupby (a monte del groupby).

# %%
print(dataset[dataset['stars']==5].groupby(['type','cool']).size())
# Succede quanto segue: anzitutto filtro i risultati sulle righe ove il campo 'stars'=5, dopodichè eseguo una groupby
# dapprima sul campo 'type', poi sul campo 'cool'
# Out:
# type    cool
# review  0       2072
#         1        660
#         2        265
#         3        131
#         4         62
#         5         43
#         6         26
#         7         13
#         8         14
#         9          7
#         10        11
#         11         7
#         12         3
#         13         3
#         14         6
#         15         1
#         16         3
#         17         4
#         19         1
#         23         1
#         27         1
#         28         1
#         32         1
#         77         1
# dtype: int64
